# %%
#Import the Pandas library
import pandas as pd
#Read the CSV data in the path provided
data = pd.read_csv(r"C:\Users\Dennis\Desktop\Employee data analysis\Employee-data-Analysis\employee_data.csv")
#Print the data to view it
data
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 0      3427     Uriah     Bridges  20-Sep-19        NaN
# 1      3428     Paula       Small  11-Feb-23        NaN
# 2      3429    Edward        Buck  10-Dec-18        NaN
# 3      3430   Michael     Riordan  21-Jun-21        NaN
# 4      3431   Jasmine       Onque  29-Jun-19        NaN
# ...     ...       ...         ...        ...        ...
# 2995   3422    Jakobe    Erickson  22-Jun-22  07-Aug-22
# 2996   3423    Adyson  Strickland  28-Dec-20        NaN
# 2997   3424   Annabel     Wilkins  09-Dec-20  04-Aug-22
# 2998   3425    Kendra       Braun  28-May-19  23-Oct-21
# 2999   3426     Chace        Kerr  27-Apr-22        NaN
#
#                         Title          Supervisor  \
# 0     Production Technician I        Peter Oneill
# 1     Production Technician I     Renee Mccormick
# 2          Area Sales Manager      Crystal Walker
# 3          Area Sales Manager      Rebekah Wright
# 4          Area Sales Manager           Jason Kim
# ...                       ...                 ...
# 2995  Production Technician I      Bethany Carter
# 2996  Production Technician I     Caroline Harris
# 2997  Production Technician I  Mr. James Castillo
# 2998  Production Technician I       Michael Woods
# 2999  Production Technician I       Javier Mccall
#
#                               ADEmail BusinessUnit          EmployeeStatus  \
# 0         uriah.bridges@bilearner.com         CCDR                  Active
# 1           paula.small@bilearner.com           EW                  Active
# 2           edward.buck@bilearner.com           PL                  Active
# 3       michael.riordan@bilearner.com         CCDR                  Active
# 4         jasmine.onque@bilearner.com          TNS                  Active
# ...                               ...          ...                     ...
# 2995    jakobe.erickson@bilearner.com          PYZ        Leave of Absence
# 2996  adyson.strickland@bilearner.com          SVG                  Active
# 2997    annabel.wilkins@bilearner.com          TNS  Voluntarily Terminated
# 2998       kendra.braun@bilearner.com          WBL  Voluntarily Terminated
# 2999         chace.kerr@bilearner.com          BPC                  Active
#
#       ...               Division         DOB State JobFunctionDescription  \
# 0     ...   Finance & Accounting  07-10-1969    MA             Accounting
# 1     ...                 Aerial  30-08-1965    MA                  Labor
# 2     ...          General - Sga  06-10-1991    MA              Assistant
# 3     ...   Finance & Accounting  04-04-1998    ND                  Clerk
# 4     ...          General - Con  29-08-1969    FL                Laborer
# ...   ...                    ...         ...   ...                    ...
# 2995  ...              Engineers  23-06-1998    MA        Model Assistant
# 2996  ...              Engineers  10-06-2001    MA               Engineer
# 2997  ...  Wireline Construction  27-01-1997    MA                Laborer
# 2998  ...                 Aerial  28-05-1954    MA                Foreman
# 2999  ...       Field Operations  11-09-1990    MA   Warehouse Technician
#
#      GenderCode LocationCode  RaceDesc MaritalDesc Performance Score  \
# 0        Female        34904     White     Widowed       Fully Meets
# 1          Male         6593  Hispanic     Widowed       Fully Meets
# 2          Male         2330  Hispanic     Widowed       Fully Meets
# 3          Male        58782     Other      Single       Fully Meets
# 4        Female        33174     Other     Married       Fully Meets
# ...         ...          ...       ...         ...               ...
# 2995     Female        44500     Other     Widowed       Fully Meets
# 2996       Male        35444     Black     Widowed       Fully Meets
# 2997       Male         6608     White      Single       Fully Meets
# 2998     Female         3807  Hispanic    Divorced       Fully Meets
# 2999     Female        57487     White     Married       Fully Meets
#
#      Current Employee Rating
# 0                          4
# 1                          3
# 2                          4
# 3                          2
# 4                          3
# ...                      ...
# 2995                       3
# 2996                       3
# 2997                       2
# 2998                       2
# 2999                       2
#
# [3000 rows x 26 columns]

# %%
# Convert the 'StartDate' and 'ExitDate' columns to datetime
data['StartDate'] = pd.to_datetime(data['StartDate'])
data['ExitDate'] = pd.to_datetime(data['ExitDate'])

# Calculate the tenure for each employee by subtracting 'StartDate' from 'ExitDate',
# and then dividing the result by the number of days in a year (365).
data['Tenure'] = (data['ExitDate'] - data['StartDate']).dt.days/ 365

#Calculate the average tenure of all employees
Average_tenure = data['Tenure'].mean()

#Print the average tenure in years of employees
print('The average tenure in years of employees is:',Average_tenure)
# Out:
# C:\Users\Dennis\AppData\Local\Temp\ipykernel_16316\416866970.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['StartDate'] = pd.to_datetime(data['StartDate'])
# The average tenure in years of employees is: 1.337318714312522
# C:\Users\Dennis\AppData\Local\Temp\ipykernel_16316\416866970.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['ExitDate'] = pd.to_datetime(data['ExitDate'])

# %%
#Import the visualization library
import plotly.express as px

#Calculate the counts of each unique value in the 'EmployeeStatus' column.
Status_counts = data['EmployeeStatus'].value_counts()

# Create a pie chart using Plotly Express.
#'names' parametre specifies the labels for the segment.
#'values' parametre specifies the values for each segment.
fig = px.pie(Status_counts, names=Status_counts.index ,values=Status_counts.values)

#Updatethe pie chart's traces to show both the percentage and label on the chart.
fig.update_traces(textinfo='percent+label')

#Display the pie chart
fig.show()

fig.write_image("Employee status.png")
# Out:
# <div>                            <div id="42bd2a56-e3dd-4ed3-90d7-40c43392ee70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42bd2a56-e3dd-4ed3-90d7-40c43392ee70")) {                    Plotly.newPlot(                        "42bd2a56-e3dd-4ed3-90d7-40c43392ee70",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"EmployeeStatus=%{label}<br>value=%{value}<extra></extra>","labels":["Active","Voluntarily Terminated","Leave of Absence","Future Start","Terminated for Cause"],"legendgroup":"","name":"","showlegend":true,"values":[2458,321,86,69,66],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlin ...
#
# var gd = document.getElementById('42

# %% [markdown]
# There are 2458 employees who are currently working (active)

# %% [markdown]
# #**FINDING THE DISTRIBUTION OF EMPLOYEES ACROSS DIFFERENT BUSINESS UNITS**

# %%
data['BusinessUnit'].value_counts()
# Out:
# BusinessUnit
# NEL     304
# SVG     304
# BPC     303
# EW      302
# PL      301
# CCDR    300
# PYZ     299
# TNS     297
# MSC     296
# WBL     294
# Name: count, dtype: int64

# %%
#Import the visualization library
import plotly.express as px

#Calculate the count of each unique value in the 'BusinessUnit' column.
units_counts = data['BusinessUnit'].value_counts()

#Create a histogam using plotly.
#'x' parametre specifies the x-value(unique business units)
#'y' parametre specifies the y-value(count of employees)
fig = px.histogram(units_counts, x=units_counts.index, y=units_counts.values)

#Update the layout. That is axis titles and the plot title.
fig.update_layout(xaxis_title = 'Business Unit', yaxis_title='Number of employees', title = 'DISTRIBUTION OF EMPLOYEES ACROSS DIFFERENT BUSINESS UNITS')

#Display the histogram
fig.show()

fig.write_image("Distribution of employees across different business units.png")
# Out:
# <div>                            <div id="77a4ecf3-a5c3-493e-ba7f-a7084ff94aa5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77a4ecf3-a5c3-493e-ba7f-a7084ff94aa5")) {                    Plotly.newPlot(                        "77a4ecf3-a5c3-493e-ba7f-a7084ff94aa5",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"BusinessUnit=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["NEL","SVG","BPC","EW","PL","CCDR","PYZ","TNS","MSC","WBL"],"xaxis":"x","y":[304,304,303,302,301,300,299,297,296,294],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# # **MOST COMMON JOB TITLE IN THE COMPANY**

# %%
data['Title'].value_counts()
# Out:
# Title
# Production Technician I         1321
# Production Technician II         516
# Area Sales Manager               297
# Production Manager               154
# Software Engineer                 90
# IT Support                        88
# Network Engineer                  55
# Sr. Network Engineer              50
# Data Analyst                      47
# BI Developer                      44
# Administrative Assistant          33
# Accountant I                      33
# Sales Manager                     30
# Senior BI Developer               30
# Database Administrator            25
# IT Manager - DB                   22
# Shared Services Manager           20
# Sr. Accountant                    13
# IT Manager - Support              11
# Director of Sales                 11
# Director of Operations            11
# IT Manager - Infra                11
# IT Director                       11
# President & CEO                   11
# BI Director                       11
# CIO                               11
# Software Engineering Manager      10
# Data Analyst                       8
# Sr. DBA                            8
# Principal Data Architect           8
# Data Architect                     5
# Enterprise Architect               5
# Name: count, dtype: int64

# %% [markdown]
# The most common job title in the company is "Production Technician I" with 1321 employees

# %% [markdown]
# #**DISTRIBUTION OF EMPLOYEES BASED ON THEIR EMPLOYEE TYPE**

# %%
data['EmployeeType'].value_counts()
# Out:
# EmployeeType
# Full-Time    1038
# Contract     1008
# Part-Time     954
# Name: count, dtype: int64

# %%
#Importing the visualizatiion library
import plotly.express as px

#Finding the counts in the 'EmployeeType' column.
Type_counts = data['EmployeeType'].value_counts()

#Create a pie chart.
#'name' parametre specifies the labels
#'Values' paremetre secifies the counts under each label
fig = px.pie(Type_counts, names=Type_counts.index, values=Type_counts.values)

#Update the chart to show both percentage and labels
fig.update_traces(textinfo='percent+label')

#Display the pie chart
fig.show()

fig.write_image("bar_chart.png")
# Out:
# <div>                            <div id="ab07b81d-c417-4087-9f05-4dccbc762fc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab07b81d-c417-4087-9f05-4dccbc762fc5")) {                    Plotly.newPlot(                        "ab07b81d-c417-4087-9f05-4dccbc762fc5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"EmployeeType=%{label}<br>value=%{value}<extra></extra>","labels":["Full-Time","Contract","Part-Time"],"legendgroup":"","name":"","showlegend":true,"values":[1038,1008,954],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"f ...
#
# var gd = document.getElementById('ab07b81d-c417-4087-9f05-4dccbc762fc5');
# var x = new MutationObse

# %%
# Out:
# 488.12133072407045

# %% [markdown]
# #**DURATION OF EMPLOYMENT IN DAYS**

# %%
#Convert the 'StartDate' and 'ExitDate' columns to datetime.
data['StartDate'] = pd.to_datetime(data['StartDate'])
data['ExitDate'] = pd.to_datetime(data['ExitDate'])

#Calculate the duration of employment for each employee in days by subtracting 'StartDate' from 'ExitDate'
data['Employee Duration'] = (data['ExitDate'] - data['StartDate']).dt.days

#Calculate the average duration of employment for all employees.
average_duration = data['Employee Duration'].mean()

average_duration
# Out:
# 488.12133072407045

# %% [markdown]
# Average days of employees are 488 days

# %% [markdown]
# #**NUMBER OF EMPLOYEES WHO HAVE EXITED THE COMPANY IN EACH YEAR**

# %%
#Convert the 'ExitDate' column to datetime.
data['ExitDate'] = pd.to_datetime(data['ExitDate'])

#Extract the year from the 'ExitDate' column and store it in the column 'ExitYear'
data['ExitYear'] = data['ExitDate'].dt.year

#Calculate the count of employee exits for each year and sort the results by year.
exit_count_by_year = data['ExitYear'].value_counts().sort_index()

exit_count_by_year
# Out:
# ExitYear
# 2018.0      4
# 2019.0     62
# 2020.0    133
# 2021.0    278
# 2022.0    460
# 2023.0    596
# Name: count, dtype: int64

# %% [markdown]
# The above output shows number of employees that exited in respective years

# %%
#Importing the visualization library
import plotly.express as px

#Convert the 'ExitDate' column in datetime.
data['ExitDate'] = pd.to_datetime(data['ExitDate'])

#Create a histogram that shows distribution of employees according to the exit years
fig = px.histogram(data['ExitDate'])

#Update the histogram by adding title in the axes and the plot title
fig.update_layout(xaxis_title = 'Dates', yaxis_title = 'Number of employees', title='DISTRIBUTION OF EXIT DATES ON EMPLOYEES')

#Display the graph
fig.show()

fig.write_image('Distributionof exit dates on employees.png')
# Out:
# <div>                            <div id="9ce08de7-c088-4464-b1bc-1531c2e76961" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ce08de7-c088-4464-b1bc-1531c2e76961")) {                    Plotly.newPlot(                        "9ce08de7-c088-4464-b1bc-1531c2e76961",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=ExitDate<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"ExitDate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ExitDate","offsetgroup":"ExitDate","orientation":"v","showlegend":true,"x":[null,null,null,null,null,null,"2023-07-03T00:00:00","2023-01-29T00:00:00",null,"2023-06-29T00:00:00",null,"2019-11-04T00:00:00","2022-11-27T00:00:00","2023-02-17T00:00:00",null,"2022-06-16T00:00:00","2023-05-12T00:00:00","2022-02-04T00:00:00",null,null,"2023-06-18T00:00:00","2020-11-06T00:00:00","2023-05-27T00:00:00","2022-12-04T00:00:00","2022-11-11T00:00:00",null,null,null,"2022-07-05T00:00:00",null,null,"2023-05-24T00:00:00","2022-06-21T00:00:00",null,"2021-10-01T00:00:00","2021-09-17T00:00:00","2021-07-18T00:00:00","2022-09-09T00:00:00",null,"2023-04-10T00:00:00",null,null,"2023-01-05T00:00:00","2019-10-28T00:00:00",null,null,null,null,"2023-04-13T00:00:00","2023-07-06T00:00:00",null,"2019-01-09T00:00:00","2023-04-02T00:00:00","2022-10-16T00:00:00","2021-05-31T00:00:00","2021-02-07T00:00:00",null,null,null,"2023-06-08T00:00:00",null,null,null,null,null,null,null,null,"2023-07-22T00:00:00",null,null,"2023-06-22T00:00:00","2021-12-20T00:00:00","2020-06-21T00:00:00","2022-08-30T00:00:00",null,null,null,null,"2023-05-10T00:00:00","2023-04-07T00:00:00",null,null,null,"2021-12-31T00:00:00","2023-06-22T00:00:00","2023-05-24T00:00:00",null,"2022-12-10T00:00:00","2023-01-22T00:00:00",null,"2022-07-04T00:00:00","2022-03-02T00:00:00","2023-01-13T00:00:00",null,null,"2022-08-25T00:00:00","2022-05-04T00:00:00","2023-01-10T00:00:00",null,"2021-02-25T00:00:00",null,"2020-08-24T00:00:00",null,null,null,"2023-07-16T00:00:00",null,"2022-06-02T00:00:00",null,"2023-02-24T00:00:00","2022-03-05T00:00:00",null,"2022-10-09T00:00:00","2023-07-24T00:00:00",null,null,"2023-07-09T00:00:00",null,"2023-01-27T00:00:00",null,"2022-10-10T00:00:00","2020-10-18T00:00:00","2022-10-14T00:00:00",null,"2020-06-03T00:00:00",null,null,"2023-05-07T00:00:00","2020-01-15T00:00:00",null,null,"2020-09-06T00:00:00",null,null,"2023-01-05T00:00:00",null,"2020-12-02T00:00:00",null,null,null,"2023-07-29T00:00:00","2020-08-28T00:00:00","2021-10-26T00:00:00","2023-07-17T00:00:00","2020-05-19T00:00:00","2021-10-17T00:00:00","2022-01-04T00:00:00","2022-01-18T00:00:00","2023-04-26T00:00:00",null,null,null,null,"2023-05-01T00:00:00","2022-05-04T00:00:00","2022-04-18T00:00:00",null,null,"2019-02-10T00:00:00","2021-12-17T00:00:00","2019-08-15T00:00:00",null,"2022-10-13T00:00:00","2023-05-29T00:00:00","2022-06-18T00:00:00",null,null,"2022-09-14T00:00:00",null,"2021-04-14T00:00:00","2023-08-05T00:00:00",null,null,null,"2023-05-24T00:00:00","2019-02-21T00:00:00","2022-08-31T00:00:00",null,"2023-01-20T00:00:00","2021-04-14T00:00:00",null,null,null,null,null,null,"2021-07-02T00:00:00","2022-09-22T00:00:00",null,null,null,"2023-05-01T00:00:00","2023-07-14T00:00:00",null,"2021-07-10T00:00:00",null,null,"2022-07-31T00:00:00",null,"2022-10-28T00:00:00",null,"2022-12-03T00:00:00",null,"2022-10-25T00:00:00","2022-10-24T00:00:00",null,"2023-07-26T00:00:00",null,null,null,null,"2020-04-14T00:00:00",null,"2021-05-01T00:00:00","2021-11-12T00:00:00",null,null,null,null,"2021-01-30T00:00:00",null,null,"2022-02-28T00:00:00",null,"2022-08-27T00:00:00","2023-07-30T00:00:00",null,null,null,null,"2023-07-07T00:00:00","2019-10-13T00:00:00",null,"2022-09-05T00:00:00",null,"2022-01-22T00:00:00","2022-01-12T00: ...

# %% [markdown]
# The trend of exit of employees increases as the year increases

# %% [markdown]
# #**SUPERVISOR WITH THE MOST EMPLOYEES UNDER THEM**

# %%
data['Supervisor'].value_counts()
# Out:
# Supervisor
# John Smith          3
# Robert Sullivan     2
# Kenneth Perry       2
# Desiree Martinez    2
# Susan Smith         2
#                    ..
# Barry Payne         1
# Paula Ross          1
# Lisa Spencer        1
# Joseph Smith        1
# Javier Mccall       1
# Name: count, Length: 2952, dtype: int64

# %% [markdown]
# John smith is the supervisor with the most employees under him.

# %% [markdown]
# #**DISTRIBUTION OF EMPLOYEES BASED ON GENDER.**

# %%
data['GenderCode'].value_counts()
# Out:
# GenderCode
# Female    1682
# Male      1318
# Name: count, dtype: int64

# %%
#Import the visualization library
import plotly.express as px

#Find the count of each value in the 'GenderCode' column.
gender_count = data['GenderCode'].value_counts()

#Create a piechart.
#'names' parameter specifies the labels for the segments.
#'Values' paremeter specifies the values for each segment.
#'Title' paremeter sets the title chart.
fig = px.pie(gender_count, names=gender_count.index, values=gender_count.values, title='DISTRIBUTION OF EMPLOYEES BASED ON GENDER')

#Update the pie chart's traces to show both the percentage and label on the chart
fig.update_traces(textinfo='percent+label')

#Display the pie chart
fig.show()


fig.write_image("Distribution on employees bsed on Gender.png")
# Out:
# <div>                            <div id="b6d00d3e-9084-4543-9104-e34d880121d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6d00d3e-9084-4543-9104-e34d880121d0")) {                    Plotly.newPlot(                        "b6d00d3e-9084-4543-9104-e34d880121d0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"GenderCode=%{label}<br>value=%{value}<extra></extra>","labels":["Female","Male"],"legendgroup":"","name":"","showlegend":true,"values":[1682,1318],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size" ...
#
# var gd = document.getElementById('b6d00d3e-9084-4543-9104-e34d880121d0');
# var x

# %% [markdown]
# Most of the employees in the company are women

# %% [markdown]
# **#DISTRIBUTION BASED ON THEIR RACE#**

# %%
data['RaceDesc'].value_counts()
# Out:
# RaceDesc
# Asian       629
# Black       618
# White       599
# Other       582
# Hispanic    572
# Name: count, dtype: int64

# %%
#Import the visualization library
import plotly.express as px

#Find the counts on each value in the 'RaceDesc' column.
race_count = data['RaceDesc'].value_counts()

#Create the pie chart.
#'names' parametre specifies the values for each segment.
#'title' parametre specifies the values for the chart.
fig = px.pie(race_count, names=race_count.index, values=race_count.values,labels=race_count.index, title='DISTRIBUTION OF EMLOYEES BASED ON RACE')

#Update the piechart's tarces to show both percentage and label on the chart.
fig.update_traces(textinfo='percent+label')

#Display the chart
fig.show()

fig.write_image("Distribution of employeesbased on race.png")
# Out:
# <div>                            <div id="8c49d853-4ea1-4efa-9f2d-fe956cd78bf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c49d853-4ea1-4efa-9f2d-fe956cd78bf0")) {                    Plotly.newPlot(                        "8c49d853-4ea1-4efa-9f2d-fe956cd78bf0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"RaceDesc=%{label}<br>value=%{value}<extra></extra>","labels":["Asian","Black","White","Other","Hispanic"],"legendgroup":"","name":"","showlegend":true,"values":[629,618,599,582,572],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pa ...
#
# var gd = document.getElementById('8c49d853-4ea1-

# %% [markdown]
# Most of the employees are Asian

# %% [markdown]
# #**DISTRIBUTION OF EMPLOYEES BASEDON THEIR MARITAL STATUS.**

# %%
data['MaritalDesc'].value_counts()
# Out:
# MaritalDesc
# Single      772
# Married     764
# Divorced    741
# Widowed     723
# Name: count, dtype: int64

# %%
#Import the visualization library
import plotly.express as px

#Calculate the counts of each unique value in the 'MaritalDesc' column.
marital_count = data['MaritalDesc'].value_counts()

# Create a pie chart.
# 'names' parameter specifies the labels for the segments.
# 'values' parameter specifies the values for each segment.
# 'title' parameter sets the title for the chart.
fig = px.pie(marital_count, names=marital_count.index, values=marital_count.values, title='DISTRIBUTION OF EMPLOYEES BASED ON THEIR MARITAL STATUS')

# Update the pie chart's traces to show both the percentage and label on the chart.
fig.update_traces(textinfo='percent+label')

#Display the pie chart.
fig.show()

fig.write_image("Distribution of employees based on their marital status.png")
# Out:
# <div>                            <div id="f973c7e0-1710-41c7-9259-dadae38859cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f973c7e0-1710-41c7-9259-dadae38859cb")) {                    Plotly.newPlot(                        "f973c7e0-1710-41c7-9259-dadae38859cb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"MaritalDesc=%{label}<br>value=%{value}<extra></extra>","labels":["Single","Married","Divorced","Widowed"],"legendgroup":"","name":"","showlegend":true,"values":[772,764,741,723],"type":"pie","textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"patter ...
#
# var gd = document.getElementById('f

# %% [markdown]
# Most of the employees single in the company

# %% [markdown]
# #**DISTRIBUTION OF EMPLOYEE PERFOMANCE BASED ON GENDER AND RACE**

# %%
#Import the visualization library
import plotly.express as px

#Create a bar chart for employee perfomance score based on Race
#'x' paraemtre specifies the cartegorical variable (RaceDesc) on the x axis.
#'y' parametre specifies the categorical variable (Perfomance Score) on the y axis.
fig_race = px.bar(data, x='RaceDesc', y='Performance Score' , title='DISTRIBUTION OF EMPLOYEES PERFOMANCE SCORE BASED ON THEIR RACE')

#Create a bar chart for employee perfomance score based on Gender
#'x' paraemtre specifies the cartegorical variable (RaceDesc) on the x axis.
#'y' parametre specifies the categorical variable (Perfomance Score) on the y axis.
fig_Gender = px.bar(data, x='GenderCode', y='Performance Score', title='DISTRIBUTION OF EMPLOYEES PERFOMANCE BASED ON THEIR GENDER')

#Display both bar graphs
fig_Gender.show()
fig_race.show()

fig_Gender.write_image("Distribution of employees based on Gender.png")
fig_race.write_image("Distribution of eployee based on their Race.png")
# Out:
# <div>                            <div id="156c9d5a-d1e4-469d-87ad-aa21bc51ad48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("156c9d5a-d1e4-469d-87ad-aa21bc51ad48")) {                    Plotly.newPlot(                        "156c9d5a-d1e4-469d-87ad-aa21bc51ad48",                        [{"alignmentgroup":"True","hovertemplate":"GenderCode=%{x}<br>Performance Score=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Female","Female","Male","Male","Female","Female","Male","Female","Male","Male","Male","Male","Female","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Female","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Male","Male","Female","Male","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Female","Male","Female","Male","Female","Female","Female","Male","Male","Male","Male","Male","Male","Female","Male","Female","Male","Female","Female","Female","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Female","Female","Male","Female","Male","Male","Male","Male","Female","Female","Female","Male","Female","Female","Male","Female","Male","Male","Female","Male","Male","Male","Female","Female","Female","Female","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Female","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Female","Female","Female","Male","Male","Male","Male","Female","Female","Male","Male","Male","Male","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Female","Female","Female","Male","Male","Male","Female","Female","Male","Male","Male","Male","Male","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Male","Female","Female","Male","Male","Male","Male","Female","Female","Male","Male","Male","Male","Male","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Female","Female","Female","Male","Male","Male","Male","Female","Female","Male","Male","Male","Male","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Female","Female","Female","Male","Male","Male","Male","Female","Female","Male","Male","Male","Male","Female","Female","Female","Female","Female","Male","Male","Male","Male","Male","Female","Female","Male","Male","Male","Male","Male","Female","Male","Male","Male","Male","Female","Female","Female","Female","Female","Male","Female","Male","Male","Male","Male","Female","Male","Male","Male","Male","Male","Female","Female","Male","Male","Male","Male","Female","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Female","Female","Male","Male","Male","Male","Male","Female","Female","Male","Male","Male","Female","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Female","Female","Male","Male","Male","Female","Male","Female","Female","Male","Male","Male","Female","Male","Female","Male","Female","Male","Male","Male","Male","Female","Male","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Female","Female","Male","Male","Male", ...
# <div>                            <div id="a4fb1f7b-5b10-44b2-9e65-7fd7512a6d4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4fb1f7b-5b10-44b2-9e65-7fd7512a6d4f")) {                    Plotly.newPlot(                        "a4fb1f7b-5b10-44b2-9e65-7fd7512a6d4f",                        [{"alignmentgroup":"True","hovertemplate":"RaceDesc=%{x}<br>Performance Score=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["White","Hispanic","Hispanic","Other","Other","Black","Hispanic","White","Black","Asian","Other","Asian","Other","White","Asian","Black","Asian","Other","Other","White","Asian","Asian","Black","Other","Other","Black","White","Hispanic","Other","Black","White","Hispanic","Black","Asian","Hispanic","Hispanic","Hispanic","Black","Asian","Other","Asian","Black","Asian","Black","Asian","Other","Hispanic","Other","Asian","Asian","Asian","Hispanic","Hispanic","Black","Other","Asian","Asian","Other","White","Other","Other","Asian","Black","Hispanic","White","Asian","Asian","Black","Other","Other","Hispanic","White","Asian","White","Other","White","Other","Hispanic","Hispanic","Other","White","Asian","Black","Hispanic","Asian","Black","Other","Asian","White","Asian","Hispanic","Hispanic","Hispanic","Black","Asian","Other","Other","Asian","Hispanic","White","Black","Hispanic","Hispanic","Black","Black","Black","White","Asian","Black","Black","Hispanic","Asian","Hispanic","White","Black","White","Black","Asian","Black","Hispanic","Other","White","Black","White","Black","White","Black","Asian","Hispanic","White","Other","Black","White","Asian","White","Other","Black","White","Other","Black","Asian","Asian","Hispanic","Asian","White","White","Asian","Hispanic","Hispanic","Asian","White","Hispanic","Asian","Other","Other","Asian","White","Other","Black","Hispanic","Other","Black","White","Asian","White","Other","Asian","Black","Other","Other","Black","Other","White","White","White","Hispanic","White","Hispanic","Other","Other","Other","Other","Other","Other","Hispanic","Black","Asian","White","Asian","Hispanic","Hispanic","Black","Asian","Hispanic","White","Hispanic","Asian","Asian","Asian","Asian","Black","Hispanic","Black","Other","Other","Asian","Hispanic","Other","Hispanic","Asian","Asian","Hispanic","Hispanic","Asian","Other","Black","Asian","Black","Asian","Hispanic","Black","Other","White","White","White","Other","Asian","Asian","Asian","Hispanic","Black","Black","Other","Hispanic","Asian","Other","Black","Other","Asian","Hispanic","Black","Asian","Black","Hispanic","Asian","Asian","Other","Other","Hispanic","Black","Hispanic","Asian","Asian","Other","Black","Black","Other","Hispanic","Asian","White","White","Asian","Asian","White","Asian","Black","White","Hispanic","Hispanic","Hispanic","Other","Hispanic","Asian","Hispanic","Other","Asian","White","Asian","White","White","Asian","Black","Black","Hispanic","Black","Asian","Hispanic","White","Black","Black","Asian","Other","Hispanic","White","Black","White","Asian","Asian","Asian","Other","Other","Hispanic","Other","Black","Hispanic","Black","Hispanic","White","White","Other","Hispanic","Hispanic","Asian","Other","Hispanic","Asian","Black","Asian","Asian","Black","Black","Other","Other","Black","Other","White","White","Black","Black","Hispanic","Asian","Other","Black","Other","Black","Black","White","Black","Hispanic","Black","Black","Black","Asian","Asian","Asian","Asian","Hispanic","Black","Other","Black","Black","Other","Other","Black","Black","Asian","Asian","White","Black","Black","White","Black","Other","Hispanic","Asian","White","Asian","Asian","White","Hispanic","Black","Other","Hispanic","Other","Hispa ...

# %% [markdown]
# In the graph showing distribution of employee perfomance based on their Gender, Females show a greater average perfomance than Males.
#
# In the graph showing distribution of employee perfomance based on ther races, Blacks show a greater average perfomance more than all the other races.

# %%
# Group the data by gender and performance score, and calculate the count
performance_by_gender = data.groupby(['GenderCode', 'Performance Score']).size().reset_index(name='Count')

# Print the results
print(performance_by_gender)
# Out:
#   GenderCode  Performance Score  Count
# 0     Female            Exceeds    243
# 1     Female        Fully Meets   1278
# 2     Female  Needs Improvement    104
# 3     Female                PIP     57
# 4       Male            Exceeds    126
# 5       Male        Fully Meets   1083
# 6       Male  Needs Improvement     73
# 7       Male                PIP     36

# %% [markdown]
# The above output indicates that more females exceeed the perfomance score more than male, more females fully meet the perfomance score more than male, More females need improvement more than males. More female pip than males.

# %%
# Group the data by gender and performance score, and calculate the count
perfomance_by_race = data.groupby(['RaceDesc','Performance Score']).size().reset_index()

# Print the results
perfomance_by_race
# Out:
#     RaceDesc  Performance Score    0
# 0      Asian            Exceeds   80
# 1      Asian        Fully Meets  499
# 2      Asian  Needs Improvement   36
# 3      Asian                PIP   14
# 4      Black            Exceeds   58
# 5      Black        Fully Meets  496
# 6      Black  Needs Improvement   42
# 7      Black                PIP   22
# 8   Hispanic            Exceeds   75
# 9   Hispanic        Fully Meets  447
# 10  Hispanic  Needs Improvement   27
# 11  Hispanic                PIP   23
# 12     Other            Exceeds   77
# 13     Other        Fully Meets  452
# 14     Other  Needs Improvement   34
# 15     Other                PIP   19
# 16     White            Exceeds   79
# 17     White        Fully Meets  467
# 18     White  Needs Improvement   38
# 19     White                PIP   15

# %%
import pandas as pd
import datetime
# Convert the 'DOB' column to datetime format.
data['DOB'] = pd.to_datetime(data['DOB'])

# Calculate the age for each employee by subtracting their birth year from the current year.
data['Age'] = (datetime.datetime.now().year - data['DOB'].dt.year)

# Group the data by 'DepartmentType' and calculate the average age for each group.
Average_age_by_department = data.groupby('DepartmentType')['Age'].mean()
Average_age_by_department
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       2 import datetime
#       3 # Convert the 'DOB' column to datetime format.
# ----> 4 data['DOB'] = pd.to_datetime(data['DOB'])
#       6 # Calculate the age for each employee by subtracting their birth year from the current year.
#       7 data['Age'] = (datetime.datetime.now().year - data['DOB'].dt.year)
#
# File ~\anaconda\Lib\site-packages\pandas\core\tools\datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File ~\anaconda\Lib\site-packages\pandas\core\tools\datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File ~\anaconda\Lib\site-packages\pandas\_libs\tslibs\strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~\anaconda\Lib\site-packages\pandas\_libs\tslibs\strptime.pyx:351, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "30-08-1965" doesn't match format "%m-%d-%Y", at position 1. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
#Import the visualization library
import plotly.express as px

# Create a box plot using Plotly Express.
# 'x' parameter specifies the categorical variable (EmployeeClassificationType) on the x-axis.
# 'y' parameter specifies the numerical variable (PayZone) on the y-axis.
# 'title' parameter sets the title for the chart.
fig = px.box(data, x='EmployeeClassificationType', y='PayZone', title='Pay Variation Across Employee Classification Types')

#Update the axes title in the graph
fig.update_layout(xaxis_title='Employee Classification Type', yaxis_title='Pay')

#Display the graph
fig.show()
# Out:
# <div>                            <div id="db6f7c6a-b425-4c4d-8920-ca982f98527e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db6f7c6a-b425-4c4d-8920-ca982f98527e")) {                    Plotly.newPlot(                        "db6f7c6a-b425-4c4d-8920-ca982f98527e",                        [{"alignmentgroup":"True","hovertemplate":"EmployeeClassificationType=%{x}<br>PayZone=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Temporary","Part-Time","Part-Time","Full-Time","Temporary","Full-Time","Temporary","Full-Time","Part-Time","Temporary","Temporary","Temporary","Temporary","Full-Time","Part-Time","Full-Time","Part-Time","Part-Time","Full-Time","Part-Time","Part-Time","Temporary","Temporary","Temporary","Full-Time","Part-Time","Part-Time","Full-Time","Temporary","Temporary","Temporary","Full-Time","Full-Time","Full-Time","Part-Time","Full-Time","Temporary","Full-Time","Full-Time","Full-Time","Part-Time","Temporary","Full-Time","Part-Time","Temporary","Full-Time","Temporary","Temporary","Temporary","Temporary","Full-Time","Temporary","Part-Time","Temporary","Part-Time","Temporary","Temporary","Full-Time","Full-Time","Temporary","Part-Time","Full-Time","Temporary","Part-Time","Full-Time","Full-Time","Full-Time","Full-Time","Temporary","Part-Time","Temporary","Full-Time","Temporary","Part-Time","Part-Time","Temporary","Temporary","Part-Time","Temporary","Temporary","Full-Time","Part-Time","Full-Time","Full-Time","Full-Time","Temporary","Temporary","Part-Time","Part-Time","Part-Time","Part-Time","Part-Time","Temporary","Temporary","Part-Time","Part-Time","Temporary","Full-Time","Temporary","Full-Time","Temporary","Part-Time","Full-Time","Part-Time","Full-Time","Full-Time","Full-Time","Full-Time","Temporary","Temporary","Part-Time","Part-Time","Temporary","Part-Time","Full-Time","Temporary","Temporary","Temporary","Temporary","Part-Time","Full-Time","Full-Time","Full-Time","Temporary","Part-Time","Full-Time","Temporary","Temporary","Temporary","Temporary","Temporary","Part-Time","Full-Time","Full-Time","Temporary","Full-Time","Full-Time","Temporary","Full-Time","Part-Time","Full-Time","Part-Time","Temporary","Temporary","Full-Time","Part-Time","Full-Time","Full-Time","Temporary","Full-Time","Temporary","Temporary","Part-Time","Full-Time","Part-Time","Part-Time","Temporary","Full-Time","Full-Time","Full-Time","Temporary","Full-Time","Temporary","Full-Time","Part-Time","Full-Time","Full-Time","Part-Time","Temporary","Full-Time","Part-Time","Full-Time","Temporary","Temporary","Full-Time","Part-Time","Part-Time","Full-Time","Temporary","Full-Time","Full-Time","Part-Time","Full-Time","Full-Time","Full-Time","Part-Time","Part-Time","Temporary","Part-Time","Full-Time","Full-Time","Temporary","Full-Time","Temporary","Full-Time","Temporary","Full-Time","Part-Time","Part-Time","Temporary","Full-Time","Part-Time","Full-Time","Full-Time","Full-Time","Full-Time","Temporary","Full-Time","Part-Time","Temporary","Full-Time","Part-Time","Full-Time","Temporary","Full-Time","Full-Time","Full-Time","Full-Time","Full-Time","Full-Time","Part-Time","Full-Time","Part-Time","Part-Time","Full-Time","Part-Time","Part-Time","Part-Time","Full-Time","Part-Time","Full-Time","Temporary","Part-Time","Full-Time","Temporary","Temporary","Full-Time","Part-Time","Temporary","Full-Time","Temporary","Full-Time","Temporary","Full-Time","Temporary","Full-Time","Temporary","Part-Time","Full-Time","Part-Time","Full-Time","Full-Time","Full-Time","Full-Time","Temporary","Temporary","Temporary","Part-Time","Full-Time","Full-Time","Temporary","Full-Time","Temporary","Temporary","Full-Time","Part-Time","Temporary","Part-Time","Temporary","Par ...

# %%
import pandas as pd
import plotly.express as px

# Assuming your dataset is in a CSV file named "employee_data.csv"

# Create an interactive bar plot using Plotly
fig = px.histogram(data, x='State', title='Distribution of Employees Across Different States')
fig.update_xaxes(title='State')
fig.update_yaxes(title='Number of Employees')
fig.update_layout(xaxis_tickangle=-45)
fig.show()


fig.write_image("Distribution of employees across different States.png")
# Out:
# <div>                            <div id="67952662-f7a3-478c-a73d-253ee2c1a90f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67952662-f7a3-478c-a73d-253ee2c1a90f")) {                    Plotly.newPlot(                        "67952662-f7a3-478c-a73d-253ee2c1a90f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"State=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["MA","MA","MA","ND","FL","CT","CA","OR","TX","TX","IN","GA","CO","KY","NV","MA","KY","KY","KY","TX","TX","TX","CO","CO","CO","IN","MA","KY","KY","KY","KY","TX","TX","TX","CO","CO","IN","MA","MA","KY","KY","KY","TX","TX","TX","TX","CO","CO","IN","MA","KY","KY","TX","TX","TX","TX","CO","CO","CO","IN","KY","KY","TX","TX","TX","CO","CO","CO","IN","CA","OR","KY","KY","TX","TX","TX","CO","CO","IN","IN","CA","OR","KY","KY","KY","TX","TX","TX","CO","CO","IN","CA","CA","ND","KY","KY","KY","TX","TX","TX","CO","CO","IN","CA","CA","OR","ND","KY","KY","GA","TX","TX","CO","CO","IN","IN","CA","CA","OR","ND","KY","KY","GA","TX","TX","CO","CO","IN","IN","CA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","CT","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","CT","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","CT","MA","MA","TX","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","TX","TX","TX","TX","TX","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","TX","TX","TX","TX","TX","MA","MA","MA","MA","MA","MA","MA","MA","TX","TX","TX","TX","MA","MA","MA","MA","MA","MA","MA","MA","MA","TX","TX","TX","TX","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA","MA ...

# %% [markdown]
# Most employees are from the state of MA
